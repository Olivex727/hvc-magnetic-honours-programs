# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [3, 6, 3, 2, 5]

plt.plot(x, y)
plt.show()

# %%
import IPython
app = IPython.Application.instance()
#app.kernel.do_shutdown(True)

# %%
import numpy as np

np.log(10)
# Out:
# 2.302585092994046

# %%
import os
os.path.abspath(".").replace("\\","/")
# Out:
# 'c:/Users/olive/OneDrive - Australian National University/Honours-Olivia/Programs/honours'

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)

plt.plot(x, norm.pdf(x, loc=0, scale=0.1))
plt.show()

# %%
import sys
sys.path.append('C://Users/olive/OneDrive - Australian National University/Honours-Olivia/Programs/honours/standard_modules')

#from plotting import honours_plot

#honours_plot.hi()
# Out:
# Hello World!

# %%
print("abc")
x = list(range(10000))
for i in x:
    print(str(i/len(x)*100)+"% \r",end="", flush=True)
# Out:
# abc
# 99.99% 0000000001%

# %%
x = list(range(10000))
for i in x:
    print(str(int(i/len(x)*100))+"% \r", sep="", end="", flush=True)
# Out:
# 99%

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u

coord = SkyCoord(ra=13.71933120325877 * u.deg, dec=-35.32777892243496 * u.deg, frame='icrs')
coord.galactic
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     (298.02681031, -81.76769098)>
