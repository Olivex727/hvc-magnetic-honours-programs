# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [3, 6, 3, 2, 5]

plt.plot(x, y)
plt.show()

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# Ayo
